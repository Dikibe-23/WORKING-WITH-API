# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np
from IPython.display import JSON

# %%
API_KEY = "AIzaSyCE2GQOyN10c5F-BOVaU4gnNdQ14JtbMtk"
channel_Id = ["UCatt7TBjfBkiJWx8khav_Gg", # you can add more channels here
            ]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey=API_KEY)
request = youtube.channels().list(part="snippet,contentDetails,statistics", id=",".join(channel_Id))
response = request.execute()

JSON(response)

# %%
def get_channel_stats(youtube, channel_Id):

    data = []

    request = youtube.channels().list(part="snippet,contentDetails,statistics", id=",".join(channel_Id))
    response = request.execute()

    # loop through items
    for item in response['items']:
        stats = {'channelName': item['snippet']['title'], 'subscribers':item['statistics']['subscriberCount'], 'views': item['statistics']['viewCount'],
                'videos':item['statistics']['videoCount'], 'playlist_Id': item['contentDetails']['relatedPlaylists']['uploads']}
        data.append(stats)
    return (pd.DataFrame(data))

# %%
channel_stats = get_channel_stats(youtube, channel_Id)
channel_stats
# Out:
#                channelName subscribers      views videos  \
# 0  Piers Morgan Uncensored     2310000  565461742   1214
#
#                 playlist_Id
# 0  UUatt7TBjfBkiJWx8khav_Gg

# %% [markdown]
# ## Getting Video Ids

# %%
# Next we want to get all playlist items from the piers_morgan's channel

playlist_Id = "UUatt7TBjfBkiJWx8khav_Gg"

def get_video_Id(youtube, playlist_Id):
    request = youtube.playlistItems().list(part="snippet,contentDetails", playlistId=playlist_Id,
                                          maxResults=50)
    response = request.execute()

    # we want the video Ids for all 50 item

    video_Ids = []

    for i in response['items']:
        videoId_data = dict(video_Id=response['items'][0]['contentDetails']['videoId'])
        video_Ids.append(videoId_data)
    return JSON(video_Ids) # or return (len(video_Ids))

# %%
# To access all video Ids on this channel

def get_video_Id(youtube, playlist_Id):
    request = youtube.playlistItems().list(part="snippet,contentDetails", playlistId=playlist_Id, maxResults=50)
    response = request.execute()

    # we want the video Ids for all 50 item
    video_Ids = []
    
    for i in range(len(response['items'])):
        #videoId_data = dict(video_Id=response['items'][i]['contentDetails']['videoId'])
        video_Ids.append(response['items'][i]['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        more_pages = True

        while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(part="snippet,contentDetails", playlistId=playlist_Id, maxResults=15,
                                                      pageToken=next_page_token)
                response = request.execute()

                for i in range(len(response['items'])):
                    #videoId_data = dict(video_Id=response['items'][i]['contentDetails']['videoId'])
                    video_Ids.append(response['items'][i]['contentDetails']['videoId'])

                next_page_token = response.get('nextPageToken')
                
        return video_Ids #return JSON(video_Ids) # or return (len(video_Ids))

# %%
video_Ids= get_video_Id(youtube, playlist_Id)
video_Ids
# Out:
# ['VwpshuisjjE',
#  'PSPSHO2rpmc',
#  'v4RhM-ByNAQ',
#  'u5_6mMV7Hc4',
#  '4PLB4qPz9Fo',
#  '375LKfyoLEk',
#  'hbqHRfIqi8I',
#  'P9oJuYb7z8I',
#  'X5IQcS90kPE',
#  'uHqs15gOv4k',
#  'qFkKw93jqAA',
#  'yPqdvr_RSwo',
#  'psUFb1DKeAM',
#  '4-qxEAwYBUw',
#  'QtcEAGG_tnU',
#  'hnt3xnDS1Cw',
#  'kyyWsU6a4lg',
#  'hzCZG38jalw',
#  'mhNYu4gElKk',
#  'oUfq7bGBH8M',
#  'oB8aBbbzxaY',
#  '51qzZ8mcxWM',
#  'ywDUcrVg7_Q',
#  'h3sn3bqIaq4',
#  'nB2PX7GZr5E',
#  'BQPxCscEEh8',
#  'xLCFPKETxvw',
#  'dmv4_w3ywn4',
#  'ghrS4PxImbw',
#  'dtRJIm1bbU4',
#  'HToB-SRD6kQ',
#  'huLe3ju0dT8',
#  'vfhp_taoOUw',
#  'k-sIbtnz1eI',
#  '-CogmBOB58s',
#  'VVEirdEcGio',
#  'OUVUJoWbTwI',
#  'ph9XF39yjgU',
#  'NpFbD0eTrB4',
#  'V4Zw-lurQjY',
#  'ERSYvw2LIv8',
#  'u8KNhzD1xDE',
#  'I_Sh-ERypMA',
#  'koIlcH3lnr8',
#  '_AKmnr5b-VM',
#  'bikFQyrMg5o',
#  'WIR6KbGwGU0',
#  '6iNqewuihMs',
#  '2pMsYSR7g78',
#  'lwzXYda33wY',
#  '2oWbDCql4JA',
#  '2-U_gWvhQWc',
#  '9jsJYHuGPms',
#  'shYi54zFluQ',
#  'kJbVq14WKNY',
# ...

# %% [markdown]
# ## Getting video details.

# %%
# def a function to get videos details

def get_video_details(youtube, video_Ids):
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=','.join(video_Ids[:50]))
    response = request.execute()

    return (response)

# %%
get_video_details(youtube, video_Ids)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '9c4avNQJQpPzRzosUDgtNkFLGzc',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'pQhIiVD5vAiwp7GFQ36RSfBOAzY',
#    'id': 'VwpshuisjjE',
#    'snippet': {'publishedAt': '2024-01-24T11:30:02Z',
#     'channelId': 'UCatt7TBjfBkiJWx8khav_Gg',
#     'title': 'LIVE: Piers Morgan Uncensored | 24-Jan-24',
#     'description': 'Subscribe to stay up-to-date on all Uncensored content.\n\nFollow Piers Morgan Uncensored on:\nTwitter: https://twitter.com/PiersUncensored\nInstagram: https://www.instagram.com/piersmorganuncensored/\nFacebook: https://www.facebook.com/piersmorganuncensored\nTikTok: https://www.tiktok.com/@piersmorganuncensored\n\nFollow Piers Morgan on:\nTwitter: https://twitter.com/piersmorgan\nInstagram: https://www.instagram.com/piersmorgan\n\nPiers Morgan Uncensored is now available on TalkTV, Fox Nation and Sky News Australia!\n\n#piersmorgan #debate #interview #talktv',
# ...

# %%
def get_video_info(youtube,video_Ids):

    allvideo_info = []

    for i in range(0, len(video_Ids), 50):
        request = youtube.videos().list(part="snippet,contentDetails,statistics", id=','.join(video_Ids[i:i+50]))
        response = request.execute()

        for video in response['items']:
            req_data = {'video_title':video['snippet']['title'], 
                        'upload_date': video['snippet']['publishedAt'],
                        'views': video['statistics']['viewCount'], 
                        'like_count': video['statistics']['likeCount'],
                        'favorite_count': video['statistics']['favoriteCount'],
                        'content_caption': video['contentDetails']['caption']}         # ['duration', 'definition', 'caption']}
                                                                                       #'comment_count': video['statistics']['commentCount'],
            allvideo_info.append(req_data)
    return (allvideo_info)

# %%
df = get_video_info(youtube, video_Ids)
df
# Out:
# [{'video_title': 'LIVE: Piers Morgan Uncensored | 24-Jan-24',
#   'upload_date': '2024-01-24T11:30:02Z',
#   'views': '0',
#   'like_count': '3',
#   'favorite_count': '0',
#   'content_caption': 'false'},
#  {'video_title': 'Israel-Hamas War: Piers Morgan Asks Mark Regev About IDF Killing Hostages And Names On Bombs',
#   'upload_date': '2023-12-19T17:00:17Z',
#   'views': '318244',
#   'like_count': '4970',
#   'favorite_count': '0',
#   'content_caption': 'false'},
#  {'video_title': 'LIVE: Cenk Uygur and Avram Grant On Palestine And Israel War | Piers Morgan Uncensored | 18-Dec-23',
#   'upload_date': '2023-12-18T21:22:50Z',
#   'views': '126329',
#   'like_count': '1548',
#   'favorite_count': '0',
#   'content_caption': 'false'},
#  {'video_title': 'Israel-Palestine War: "There Is No Deal With The Devil!" Cenk Uygur vs Mosab Hassan Yousef On Hamas',
#   'upload_date': '2023-12-18T21:22:11Z',
#   'views': '1473095',
#   'like_count': '26028',
#   'favorite_count': '0',
# ...

# %%
data = pd.DataFrame(df)
data
# Out:
#                                             video_title           upload_date  \
# 0             LIVE: Piers Morgan Uncensored | 24-Jan-24  2024-01-24T11:30:02Z
# 1     Israel-Hamas War: Piers Morgan Asks Mark Regev...  2023-12-19T17:00:17Z
# 2     LIVE: Cenk Uygur and Avram Grant On Palestine ...  2023-12-18T21:22:50Z
# 3     Israel-Palestine War: "There Is No Deal With T...  2023-12-18T21:22:11Z
# 4     "So Palestine Shouldn't Have Their Own State?"...  2023-12-18T17:00:09Z
# ...                                                 ...                   ...
# 1158      Sharon Osbourne Joins Piers Morgan on TalkTV!  2022-03-18T14:13:23Z
# 1159  Cristiano Ronaldo, Joe Biden and More | Piers ...  2022-03-14T16:44:16Z
# 1160  Prince Harry, The Metaverse and More | Piers M...  2022-03-11T16:37:01Z
# 1161                 Welcome To Piers Morgan Uncensored  2022-03-09T14:36:54Z
# 1162  Piers Morgan: I'm Back, One Year On From My GM...  2022-03-09T11:10:24Z
#
# ...

# %%
import datetime as dt
data['upload_date'] = pd.to_datetime(data['upload_date'])
data['views'] = pd.to_numeric(data['views'])
data['like_count'] = pd.to_numeric(data['like_count'])
data['favorite_count'] = pd.to_numeric(data['favorite_count'])
data['content_caption'] = data['content_caption'].astype(str)
#date = str(date).split("T")[0]
#data.dtypes()
data
# Out:
#                                             video_title  \
# 0             LIVE: Piers Morgan Uncensored | 24-Jan-24
# 1     Israel-Hamas War: Piers Morgan Asks Mark Regev...
# 2     LIVE: Cenk Uygur and Avram Grant On Palestine ...
# 3     Israel-Palestine War: "There Is No Deal With T...
# 4     "So Palestine Shouldn't Have Their Own State?"...
# ...                                                 ...
# 1158      Sharon Osbourne Joins Piers Morgan on TalkTV!
# 1159  Cristiano Ronaldo, Joe Biden and More | Piers ...
# 1160  Prince Harry, The Metaverse and More | Piers M...
# 1161                 Welcome To Piers Morgan Uncensored
# 1162  Piers Morgan: I'm Back, One Year On From My GM...
#
#                    upload_date    views  like_count  favorite_count  \
# 0    2024-01-24 11:30:02+00:00        0           3               0
# 1    2023-12-19 17:00:17+00:00   318244        4970               0
# 2    2023-12-18 21:22:50+00:00   126329        1548               0
# ...

# %%
data.dtypes
# Out:
# video_title                     object
# upload_date        datetime64[ns, UTC]
# views                            int64
# like_count                       int64
# favorite_count                   int64
# content_caption                 object
# dtype: object

# %%
#data['month'] = data['upload_date'].dt.month
#df['Month'] = df['InsertedDate'].dt.strftime('%m')
#data['month'] = data['upload_date'].dt.strftime('%m')
data['month'] = data['upload_date'].dt.strftime('%b')
data
# Out:
#                                             video_title  \
# 0             LIVE: Piers Morgan Uncensored | 24-Jan-24
# 1     Israel-Hamas War: Piers Morgan Asks Mark Regev...
# 2     LIVE: Cenk Uygur and Avram Grant On Palestine ...
# 3     Israel-Palestine War: "There Is No Deal With T...
# 4     "So Palestine Shouldn't Have Their Own State?"...
# ...                                                 ...
# 1158      Sharon Osbourne Joins Piers Morgan on TalkTV!
# 1159  Cristiano Ronaldo, Joe Biden and More | Piers ...
# 1160  Prince Harry, The Metaverse and More | Piers M...
# 1161                 Welcome To Piers Morgan Uncensored
# 1162  Piers Morgan: I'm Back, One Year On From My GM...
#
#                    upload_date    views  like_count  favorite_count  \
# 0    2024-01-24 11:30:02+00:00        0           3               0
# 1    2023-12-19 17:00:17+00:00   318244        4970               0
# 2    2023-12-18 21:22:50+00:00   126329        1548               0
# ...

# %%
# Save the extracted data to csv file

data.to_csv('piers_morganYT.csv', index=False)

# %%
videos_per_month = data.month.value_counts(ascending=True).reset_index()
videos_per_month
# Out:
#    month  count
# 0    Feb     53
# 1    Jan     55
# 2    Mar     64
# 3    Dec     77
# 4    Apr     77
# 5    Aug     91
# 6    Jul     97
# 7    Nov    102
# 8    Oct    122
# 9    Jun    126
# 10   Sep    132
# 11   May    167

# %%
data.month.unique()

# %%
# Get comments on videos

def get_video_comments(youtube, videoId):

    comments = []

    for i in videoId:
        request = youtube.commentThreads().list(part="snippet,replies", videoId=videoId)
        response = request.execute()

        video_comments = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items']:]
        comments_ = {'videoId': videoId, 'comments': video_comments}
        comments.appen(comments_)
    
    return pd.DataFrame(comments)

# %% [markdown]
# ## Conclusion
#
# A recap of what we have tried to demonstrate in the code lines above. The aim was to use python to extract some data from a YouTube channel which in our case was Piers Morgan's channel.
#
# We obtained an API key from google, the channel ID of the YouTube channel we wish to extract data from and other relevant Ids related to what we wish to extract.
#
# We first obtained general info about the channel which are the <b> channelName, Total views, PlaylistId, total likes</b> etc. Then we went on to getsome statistics about the videos posted on the channel.
#
# We converted the extracted data into a pandas data frame and saved our data as a csv file.
#
# NOTE: whenever we refresh this lines of code we get the latest statistics on the channel.

# %% [markdown]
# ## Up next;
#
# I will do some analysis on the extracted data in a separate project. Thank you for going through my work.
